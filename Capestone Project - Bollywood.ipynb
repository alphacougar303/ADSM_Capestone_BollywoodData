# %% [markdown]
# # Capestone Project 1 - Bollywood

# %%
import pandas as pd

# %%
BollywoodData=pd.read_csv("bollywood.csv")

# %%
BollywoodData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
BollywoodData['Release Date'] = pd.to_datetime(BollywoodData['Release Date'])

# %%
BollywoodData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %% [markdown]
# 1. How many records are present in the dataset? Print the metadata information of the dataset.

# %%
BollywoodData
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
BollywoodData.shape
# Out:
# (149, 10)

# %% [markdown]
# There are 149 rows and 10 column in the dataset.

# %%
BollywoodData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %% [markdown]
# Above description is the metadata of the dataset.

# %% [markdown]
# 2. How many movies released in each genre? Which genre had highest number of releases? Sort number of releases in each genre in descending order.

# %%
BollywoodS=BollywoodData['Genre'].str.strip().value_counts()
BollywoodS
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %% [markdown]
# Above descibes the number of movies released in each gener. Comedy has hightest number of release i.e., 36.

# %%
Genre = BollywoodData.groupby("Genre")
type(Genre)
Genre.size()
# Out:
# Genre
#  Drama       35
# Action       21
# Action        3
# Comedy       36
# Romance      25
# Thriller     26
# Thriller      3
# dtype: int64

# %% [markdown]
# Above desciption is number of release in each gener using "groupby" and "size".

# %%
BollywoodData['Genre'].value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %% [markdown]
# Above desciption is number of release in each gener using "value_counts" and it result is in descending order.

# %%
BollywoodData = BollywoodData.sort_values("Release Date", ascending = False)
BollywoodData
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 143   144   2015-02-20                     Badlapur          FS     Action
# ..    ...          ...                          ...         ...        ...
# 11     12   2013-01-18                       Inkaar           N    Romance
# 9      10   2013-01-11                    Gangoobai           N     Drama
# 7       8   2013-01-11   Matru Ki Bijlee Ka Mandola           N     Comedy
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 3       4   2013-01-04             Rajdhani Express           N     Drama
#
# ...

# %%
BollywoodData = BollywoodData.sort_values(["Genre", "Release Date"], ascending = False)
BollywoodData
# Out:
#      SlNo Release Date                  MovieName ReleaseTime      Genre  \
# 20     21   2013-02-01                      David           N  Thriller
# 16     17   2013-01-25                     Race 2          LW  Thriller
# 1       2   2013-01-04               Table No. 21           N  Thriller
# 145   146   2015-03-13                       NH10           N   Thriller
# 140   141   2015-01-30                Khamoshiyan           N   Thriller
# ..    ...          ...                        ...         ...        ...
# 33     34   2013-02-22                Kai Po Che!           N     Drama
# 27     28   2013-02-08  ABCD _ Any Body Can Dance           N     Drama
# 25     26   2013-02-08                 Special 26           N     Drama
# 9      10   2013-01-11                  Gangoobai           N     Drama
# 3       4   2013-01-04           Rajdhani Express           N     Drama
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %% [markdown]
# Sorted both "ReleaseDate" and "Genre" and compare the same.

# %% [markdown]
# 3. How many movies in each genre got released in different release times like long weekend, festive season, etc. (Note: Do a cross-tabulation b/w Genre and ReleaseTime).

# %%
pd.crosstab(BollywoodData['Genre'].str.strip(),BollywoodData['ReleaseTime'])
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
# Action        3   3   3  15
# Comedy        3   5   5  23
# Drama         4   6   1  24
# Romance       3   3   4  15
# Thriller      4   1   2  22

# %% [markdown]
# 4. Which month of the year, maximum number movie releases are seen? (Note: Extract a new column called month from ReleaseDate column.)

# %%
import numpy as np
import datetime

# %%
BollywoodData['year'] = pd.DatetimeIndex(BollywoodData['Release Date']).year
BollywoodData['month'] = pd.DatetimeIndex(BollywoodData['Release Date']).month

# %%
BollywoodData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 20 to 3
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
#  10  year                 149 non-null    int64
#  11  month                149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(3)
# memory usage: 15.1+ KB

# %%
pd.crosstab(BollywoodData['month'],BollywoodData['year'])
# Out:
# year   2013  2014  2015
# month
# 1         8     7     5
# 2         6     6     4
# 3         8     8     3
# 4         5     6     0
# 5         6    12     0
# 6         5     5     0
# 7         9     7     0
# 8         4     4     0
# 9         5     5     0
# 10        6     3     0
# 11        5     5     0
# 12        0     2     0

# %%
BollywoodData['month'].value_counts()
# Out:
# 1     20
# 3     19
# 5     18
# 2     16
# 7     16
# 4     11
# 11    10
# 9     10
# 6     10
# 10     9
# 8      8
# 12     2
# Name: month, dtype: int64

# %%
pd.crosstab(BollywoodData['month'],BollywoodData['year']).value_counts()
# Out:
# 2013  2014  2015
# 5     5     0       3
# 0     2     0       1
# 4     4     0       1
# 5     6     0       1
# 6     3     0       1
#       6     4       1
#       12    0       1
# 8     7     5       1
#       8     3       1
# 9     7     0       1
# dtype: int64

# %% [markdown]
# Above describes the crosstabs of dataset by month and year. Maximum number of movies are released in January.

# %% [markdown]
# 5. Which month of the year typically sees most releases of high budgeted movies, that is, movies with the budget of 25 crore or more?

# %%
High_budgeted_movies = BollywoodData[BollywoodData["Budget"] >= 25]
High_budgeted_movies
# Out:
#      SlNo Release Date                             MovieName ReleaseTime  \
# 16     17   2013-01-25                                Race 2          LW
# 73     74   2014-08-29                        Raja Natwarlal           N
# 114   115   2014-04-11                     Bhootnath Returns          LW
# 117   118   2013-08-23                           Madras Cafe           N
# 116   117   2013-08-15  Once Upon Ay Time In Mumbai Dobaara!          FS
# ..    ...          ...                                   ...         ...
# 134   135   2013-09-20               Phata Poster Nikla Hero           N
# 118   119   2013-08-30                            Satyagraha           N
# 101   102   2013-07-12                    Bhaag Milkha Bhaag           N
# 33     34   2013-02-22                           Kai Po Che!           N
# 25     26   2013-02-08                            Special 26           N
#
#          Genre  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# ...

# %%
BollywoodData[BollywoodData["Budget"] >= 25][['month','Budget']].value_counts()
# Out:
# month  Budget
# 7      30        3
# 1      25        2
# 2      30        2
#        50        2
# 11     35        2
# 2      40        2
# 8      35        2
# 1      60        2
# 6      35        2
# 8      50        1
# 9      35        1
# 8      60        1
#        75        1
#        90        1
#        100       1
# 7      100       1
# 9      25        1
#        30        1
# 10     50        1
# 9      40        1
#        75        1
# 10     85        1
#        125       1
#        140       1
# 11     30        1
#        48        1
#        50        1
#        115       1
# 12     85        1
# 7      35        1
# 6      50        1
# 7      27        1
# 3      30        1
# 1      33        1
#        40        1
#        120       1
# 2      27        1
#        36        1
#        42        1
# 3      25        1
#        26        1
#        27        1
#        28        1
#        32        1
# 6      75        1
# 3      50        1
# ...

# %%
BollywoodData[['Budget','month']].value_counts()
# Out:
# Budget  month
# 12      2        3
# 10      7        3
#         3        3
# 30      7        3
# 5       3        3
#                 ..
# 15      5        1
#         3        1
#         1        1
# 14      10       1
# 150     5        1
# Length: 123, dtype: int64

# %% [markdown]
# 6. What are the top 10 movies with maximum return on investment(ROI)? Calculate return on investment(ROI) as (BoxOfficeCollection - Budget)/Budget.

# %%
BollywoodData['ROI'] = ((BollywoodData['BoxOfficeCollection'] - BollywoodData['Budget'])/BollywoodData['Budget'])
BollywoodData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 20 to 3
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
#  10  year                 149 non-null    int64
#  11  month                149 non-null    int64
#  12  ROI                  149 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(3)
# memory usage: 20.4+ KB

# %%
BollywoodData = BollywoodData.sort_values(["MovieName", "ROI"], ascending = False)

# %%
BollywoodData.sort_values(by=['ROI'],ascending = False).iloc[:10,[2,10]]
# Out:
#                      MovieName  year
# 64                  Aashiqui 2  2013
# 89                          PK  2014
# 132                Grand Masti  2013
# 135               The Lunchbox  2013
# 87                      Fukrey  2013
# 58                    Mary Kom  2014
# 128                     Shahid  2013
# 37   Humpty Sharma Ki Dulhania  2014
# 101         Bhaag Milkha Bhaag  2013
# 115            Chennai Express  2013

# %% [markdown]
# Above is the list of top 10 movies with maximum ROI.

# %%
BollywoodData['ROI'].nlargest(n=10)
# Out:
# 64     8.166667
# 89     7.647059
# 132    7.514286
# 135    7.500000
# 87     6.240000
# 58     5.933333
# 128    5.666667
# 37     5.500000
# 101    4.466667
# 115    4.266667
# Name: ROI, dtype: float64

# %% [markdown]
# 7. Do the movies have higher ROI if they get released on festive seasons or long weekend? Calculate the average ROI for different release time.

# %%
BollywoodData[['MovieName','ROI','ReleaseTime']]
# Out:
#                      MovieName       ROI ReleaseTime
# 35             Zilla Ghaziabad -0.555556           N
# 88                         Zid -0.297500           N
# 130                    Zanjeer -0.757333          LW
# 86                 Youngistaan -0.740385           N
# 82     Yeh Jawaani Hai Deewani  3.442857           N
# ..                         ...       ...         ...
# 51                       Aatma  0.097500           N
# 64                  Aashiqui 2  8.166667           N
# 27   ABCD _ Any Body Can Dance  2.666667           N
# 44                          3G  0.164000           N
# 0                     2 States  1.888889          LW
#
# [149 rows x 3 columns]

# %%
BollywoodData[BollywoodData['ReleaseTime'] == 'FS']
# Out:
#      SlNo Release Date                             MovieName ReleaseTime  \
# 125   126   2013-10-11                     War Chhod Na Yaar          FS
# 128   129   2013-10-18                                Shahid          FS
# 121   122   2013-11-08                               Satya 2          FS
# 40     41   2013-03-08      Saheb, Biwi Aur Gangster Returns          FS
# 142   143   2015-02-13                                   Roy          FS
# 122   123   2013-11-15                                 Rajjo          FS
# 116   117   2013-08-15  Once Upon Ay Time In Mumbai Dobaara!          FS
# 31     32   2013-02-15                              Murder 3          FS
# 119   120   2013-11-01                              Krrish 3          FS
# 23     24   2014-10-02                                Haider          FS
# 62     63   2013-04-19                         Ek Thi Daayan          FS
# 115   116   2013-08-09                       Chennai Express          FS
# ...

# %%
BollywoodData.groupby('ReleaseTime')['ROI'].mean()
# Out:
# ReleaseTime
# FS    0.973853
# HS    0.850867
# LW    1.127205
# N     0.657722
# Name: ROI, dtype: float64

# %%
BollywoodData.groupby('ReleaseTime')['ROI'].median()
# Out:
# ReleaseTime
# FS    0.466667
# HS    0.084545
# LW    1.105263
# N     0.150000
# Name: ROI, dtype: float64

# %%
print(BollywoodData.groupby('ReleaseTime')['ROI'].median().plot())
BollywoodData.groupby('ReleaseTime')['ROI'].median().plot()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# <AxesSubplot:xlabel='ReleaseTime'>

# %% [markdown]
# 8. Draw a histogram and distribution plot to find out the distribution of movie budgets. Interpret the plot to conclude if the most movies are high or the low budget movies.

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
plt.hist(BollywoodData['Budget']);

# %% [markdown]
# Most movies are low budget movies.

# %%
sn.distplot(BollywoodData['Budget']);
# Out:
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 9. Compare the distribution of ROIs b/w movies with Comedy genre and drama. Which genre typically sees higher ROIs?

# %%
sn.distplot(BollywoodData[BollywoodData['Genre'] == 'Comedy']['ROI'],color='g',label='COMEDY')
sn.distplot(BollywoodData[BollywoodData['Genre'] == 'Thriller']['ROI'],color='r',label='THRILLER');
plt.legend();
# Out:
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see above plot is for Comedy and Thriller genre movies. And Thriller has higher ROI.

# %%
sn.distplot(BollywoodData[BollywoodData['Genre'] == 'Drama']['ROI'],color='g',label='Drama')
sn.distplot(BollywoodData[BollywoodData['Genre'] == 'Comedy']['ROI'],color='r',label='Comedy');
plt.legend();
# Out:
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ashwa\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Syntax which we have used for "Comedy and Thriller" is not giving proper result from "Comedy and Drama". But as per our observation Comdey has highest ROI.

# %%
plt.hist(BollywoodData['Genre']);

# %%
sn.boxplot(y='ROI', x='Genre', data=BollywoodData);

# %% [markdown]
# Above is the scatter plot and box plot for genre.

# %% [markdown]
# 10. Is there a correlation b/w box office collection and YouTube likes? Is correleation positive or negative?

# %%
correla_data = ['BoxOfficeCollection','YoutubeLikes']
sn.pairplot(BollywoodData[correla_data], size=2)
# Out:
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Yes, there is a correlation b/w Box office collection and Youtubes likes. And we can see movies having high box office collection have large number of you tube likes.

# %%
BollywoodData[correla_data].corr()
# Out:
#                      BoxOfficeCollection  YoutubeLikes
# BoxOfficeCollection             1.000000      0.682517
# YoutubeLikes                    0.682517      1.000000

# %%
sn.heatmap(BollywoodData[correla_data].corr(), annot=True);

# %% [markdown]
# Above is the heatmap of correlation b/w box office collection and youtube likes.

# %% [markdown]
# 11. Which genre of movies typically sees more YouTubes likes? Draw boxplots for each genre of movie to compare.

# %%
sn.boxplot(y='Genre', x='YoutubeLikes', data=BollywoodData);

# %% [markdown]
# From above boxplot we can conclude that Action movies has more Youtube likes.

# %% [markdown]
# 12. Which of the variables among Budget, BoxOfficeCollection, YouTubeViews, YouTubeLikes, YouTubeDisliks are highly correlated? Note: Draw pair plot or heatmap.

# %%
correla_data_1 = ['Budget','BoxOfficeCollection','YoutubeViews','YoutubeLikes','YoutubeDislikes']
sn.pairplot(BollywoodData[correla_data_1], size=5)
# Out:
# C:\Users\ashwa\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# From above pair plot and below heatmap we can see Budget is highly correleated to other factors.

# %%
sn.heatmap(BollywoodData[correla_data_1].corr(), annot=True);
